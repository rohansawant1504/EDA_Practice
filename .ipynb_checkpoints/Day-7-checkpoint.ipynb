# %% [markdown]
# # Pivot

# %%
import pandas as pd

# %%
df1=pd.read_csv('df3.csv')

# %%
df1
# Out:
#    Unnamed: 0       city  avg_pop  temp
# 0           0       pune       23   NaN
# 1           1   banglore       66   NaN
# 2           2     mumbai      788   NaN
# 3           0  ratnagiri       45  35.0
# 4           1     nagpur       78  45.0
# 5           2      thane       96  40.0

# %%
df1.pivot(index='city',columns='Unnamed: 0')
# Out:
#            avg_pop               temp
# Unnamed: 0       0     1      2     0     1     2
# city
# banglore       NaN  66.0    NaN   NaN   NaN   NaN
# mumbai         NaN   NaN  788.0   NaN   NaN   NaN
# nagpur         NaN  78.0    NaN   NaN  45.0   NaN
# pune          23.0   NaN    NaN   NaN   NaN   NaN
# ratnagiri     45.0   NaN    NaN  35.0   NaN   NaN
# thane          NaN   NaN   96.0   NaN   NaN  40.0

# %%
df1.pivot(index='city',columns='Unnamed: 0',values='temp')
# Out:
# Unnamed: 0     0     1     2
# city
# banglore     NaN   NaN   NaN
# mumbai       NaN   NaN   NaN
# nagpur       NaN  45.0   NaN
# pune         NaN   NaN   NaN
# ratnagiri   35.0   NaN   NaN
# thane        NaN   NaN  40.0

# %% [markdown]
# ## indexing to Date

# %%
df1.set_index('Unnamed: 0')
# Out:
#                  city  avg_pop  temp
# Unnamed: 0
# 0                pune       23   NaN
# 1            banglore       66   NaN
# 2              mumbai      788   NaN
# 0           ratnagiri       45  35.0
# 1              nagpur       78  45.0
# 2               thane       96  40.0

# %%
df1.reset_index(inplace=True)

# %%
df1
# Out:
#         city  Unnamed: 0  avg_pop  temp
# 0       pune           0       23   NaN
# 1   banglore           1       66   NaN
# 2     mumbai           2      788   NaN
# 3  ratnagiri           0       45  35.0
# 4     nagpur           1       78  45.0
# 5      thane           2       96  40.0

# %%
df1.set_index('city')
# Out:
#            Unnamed: 0  avg_pop  temp
# city
# pune                0       23   NaN
# banglore            1       66   NaN
# mumbai              2      788   NaN
# ratnagiri           0       45  35.0
# nagpur              1       78  45.0
# thane               2       96  40.0

# %%
df.loc['pune']   # here indexing not done becouse of inplace is not done True
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# C:\ProgramData\anaconda3\Lib\site-packages\pandas\core\generic.py in ?(cls, axis)
#     552             return cls._AXIS_TO_AXIS_NUMBER[axis]
#     553         except KeyError:
# --> 554             raise ValueError(f"No axis named {axis} for object type {cls.__name__}")
#
# KeyError: 'pune'
#
# During handling of the above exception, another exception occurred:
#
# ValueError                                Traceback (most recent call last)
# ~\AppData\Local\Temp\ipykernel_14984\1925306697.py in ?()
# ----> 1 df.loc('pune')
#
# C:\ProgramData\anaconda3\Lib\site-packages\pandas\core\indexing.py in ?(self, axis)
#     718         # we need to return a copy of ourselves
#     719         new_self = type(self)(self.name, self.obj)
#     720
#     721         if axis is not None:
# ...

# %%
df1.set_index('city',inplace=True)

# %%
df1.loc['pune']
# Out:
# Unnamed: 0     0.0
# avg_pop       23.0
# temp           NaN
# Name: pune, dtype: float64

# %%
df1.loc['pune','temp']  # here row and column can access
# Out:
# nan

# %% [markdown]
# # Melt

# %% [markdown]
# ## if no. of column lots of and we want only read 3 - 4 column then melt is use

# %%
pd.melt(df1,id_vars=['avg_pop','temp'])
# Out:
#    avg_pop  temp    variable  value
# 0       23   NaN  Unnamed: 0      0
# 1       66   NaN  Unnamed: 0      1
# 2      788   NaN  Unnamed: 0      2
# 3       45  35.0  Unnamed: 0      0
# 4       78  45.0  Unnamed: 0      1
# 5       96  40.0  Unnamed: 0      2
