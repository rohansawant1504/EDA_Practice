# %%
import pandas as pd

# %%
d = {
    'name':['a','b','c',],
     'id':['101','102','103'],
     'address':['pune','mumbai','delhi']
    }

# %%
df = pd.DataFrame(d)

# %%
type(df['name'])
# Out:
# pandas.core.series.Series

# %%
type(df)
# Out:
# pandas.core.frame.DataFrame

# %%
pd.read_csv('food-price-index-september-2023-index-numbers.csv')
# Out:
#       Series_reference   Period   Data_value STATUS  UNITS  \
# 0           CPIM.SE901  1960.01    45.923461  FINAL  Index
# 1           CPIM.SE901  1960.02    45.498637  FINAL  Index
# 2           CPIM.SE901  1960.03    45.116296  FINAL  Index
# 3           CPIM.SE901  1960.04    45.158779  FINAL  Index
# 4           CPIM.SE901  1960.05    45.286226  FINAL  Index
# ...                ...      ...          ...    ...    ...
# 12863    CPIM.SE901502  2023.05  1347.000000  FINAL  Index
# 12864    CPIM.SE901502  2023.06  1361.000000  FINAL  Index
# 12865    CPIM.SE901502  2023.07  1366.000000  FINAL  Index
# 12866    CPIM.SE901502  2023.08  1367.000000  FINAL  Index
# 12867    CPIM.SE901502  2023.09  1370.000000  FINAL  Index
#
#                            Subject  \
# 0      Consumers Price Index - CPI
# 1      Consumers Price Index - CPI
# 2      Consumers Price Index - CPI
# 3      Consumers Price Index - CPI
# 4      Consumers Price Index - CPI
# ...                            ...
# ...

# %%
pd.read_csv("C:\Users\rohan\EDA_Practice\food-price-index-september-2023-index-numbers.csv")
# Out:
#   Cell In[11], line 1
#     pd.read_csv("C:\Users\rohan\EDA_Practice\food-price-index-september-2023-index-numbers.csv")
#                                                                                                ^
# SyntaxError: (unicode error) 'unicodeescape' codec can't decode bytes in position 2-3: truncated \UXXXXXXXX escape

# %%
# must be enter \\

# %%
pd.read_csv("C:\\Users\\rohan\\EDA_Practice\\food-price-index-september-2023-index-numbers.csv")
# Out:
#       Series_reference   Period   Data_value STATUS  UNITS  \
# 0           CPIM.SE901  1960.01    45.923461  FINAL  Index
# 1           CPIM.SE901  1960.02    45.498637  FINAL  Index
# 2           CPIM.SE901  1960.03    45.116296  FINAL  Index
# 3           CPIM.SE901  1960.04    45.158779  FINAL  Index
# 4           CPIM.SE901  1960.05    45.286226  FINAL  Index
# ...                ...      ...          ...    ...    ...
# 12863    CPIM.SE901502  2023.05  1347.000000  FINAL  Index
# 12864    CPIM.SE901502  2023.06  1361.000000  FINAL  Index
# 12865    CPIM.SE901502  2023.07  1366.000000  FINAL  Index
# 12866    CPIM.SE901502  2023.08  1367.000000  FINAL  Index
# 12867    CPIM.SE901502  2023.09  1370.000000  FINAL  Index
#
#                            Subject  \
# 0      Consumers Price Index - CPI
# 1      Consumers Price Index - CPI
# 2      Consumers Price Index - CPI
# 3      Consumers Price Index - CPI
# 4      Consumers Price Index - CPI
# ...                            ...
# ...

# %%
pd.read_excel("D:\Downloads\Vacancies.xls.xlsx")   ## for read exel file no need to give \\ for navigate location of file
# Out:
#     sno             Division              Office  \
# 0     1  SINDHUDURG DIVISION          Adavli B.O
# 1     2  SINDHUDURG DIVISION            Anav B.O
# 2     3  SINDHUDURG DIVISION           Ansur B.O
# 3     4  SINDHUDURG DIVISION            Aros B.O
# 4     5  SINDHUDURG DIVISION       Avalegaon B.O
# ..  ...                  ...                 ...
# 65   66  SINDHUDURG DIVISION          Vazare B.O
# 66   67  SINDHUDURG DIVISION           Veral B.O
# 67   68  SINDHUDURG DIVISION           Verle B.O
# 68   69  SINDHUDURG DIVISION         Wagheri B.O
# 69   70  SINDHUDURG DIVISION  Wairy Bhutnath B.O
#
#                                    name  Unnamed: 4
# 0    GDS ABPM - UR - Rs.10000 (Marathi)          32
# 1     GDS BPM - UR - Rs.12000 (Marathi)          12
# 2    GDS ABPM - UR - Rs.10000 (Marathi)          33
# 3    GDS ABPM - UR - Rs.10000 (Marathi)          34
# 4     GDS BPM - UR - Rs.12000 (Marathi)          13
# ..                                  ...         ...
# ...

# %%
# Read by Tuple

# %%
data = [
        (101,'a','pune'),
        (102,' b','mumbai'),
        (103,'c','delhi')
]

# %%
pd.DataFrame(data)  # this results show no column name
# Out:
#      0   1       2
# 0  101   a    pune
# 1  102   b  mumbai
# 2  103   c   delhi

# %%
# so we can specify column name

# %%
pd.DataFrame(data, columns=['id','name','city'])
# Out:
#     id name    city
# 0  101    a    pune
# 1  102    b  mumbai
# 2  103    c   delhi

# %%
# if we recieved data from customer in json format so we can read by api

# %%
pd.read_json('https://fake-json-api.mock.beeceptor.com/companies')
# Out:
#     id                        name                address         zip  \
# 0    1                 Barrows LLC       4001 Virgil Road  94212-0226
# 1    2  Dickens, Osinski and Moore       9660 Roslyn Flat       44531
# 2    3            Baumbach - Mante     65187 Lebsack Lake  78051-6047
# 3    4               Stracke Group      33743 Amiya Walks  24858-5484
# 4    4                Nolan - Kihn  77516 Parker Crescent       60365
# 5    5              Kunze and Sons     1673 Robbie Summit       09864
# 6    6            Johnston - Zieme        87924 Park Road  64085-1484
# 7    7               Kovacek Group      42275 14th Street       88377
# 8    8           Treutel - Wuckert     42974 S 2nd Street       94130
# 9    9                  Lowe Group        384 Berry Pines       45489
# 10  10             Larson and Sons  62571 Wellington Road       01344
#
#                       country  employeeCount    industry   marketCap  \
# ...

# %%
# data from our own django api project 
pd.read_json("http://127.0.0.1:8000/api/get-post/emplist/")
# Out:
#    emp_id emp_name  emp_sal emp_city
# 0       1    rohan       10     pune
# 1       2    rohan       10     pune
# 2       3    rohan       10     pune
