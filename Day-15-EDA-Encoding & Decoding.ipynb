# %%
import pandas as pd

# %%
import numpy as np

# %%
df = pd.read_csv('Pune_House_Price_Data.csv')

# %%
df
# Out:
#                   area_type   availability       size  society total_sqft  \
# 0      Super built-up  Area         19-Dec      2 BHK  Coomee        1056
# 1                Plot  Area  Ready To Move  4 Bedroom  Theanmp       2600
# 2            Built-up  Area  Ready To Move      3 BHK      NaN       1440
# 3      Super built-up  Area  Ready To Move      3 BHK  Soiewre       1521
# 4      Super built-up  Area  Ready To Move      2 BHK      NaN       1200
# ...                     ...            ...        ...      ...        ...
# 13315        Built-up  Area  Ready To Move  5 Bedroom  ArsiaEx       3453
# 13316  Super built-up  Area  Ready To Move      4 BHK      NaN       3600
# 13317        Built-up  Area  Ready To Move      2 BHK  Mahla T       1141
# 13318  Super built-up  Area         18-Jun      4 BHK  SollyCl       4689
# 13319  Super built-up  Area  Ready To Move      1 BHK      NaN        550
#
#        bath  balcony   price         site_location
# ...

# %%
df.area_type.unique()
# Out:
# array(['Super built-up  Area', 'Plot  Area', 'Built-up  Area',
#        'Carpet  Area'], dtype=object)

# %% [markdown]
# ## By using get_dummies

# %%
df1 = pd.get_dummies(df.area_type)

# %%
df1
# Out:
#        Built-up  Area  Carpet  Area  Plot  Area  Super built-up  Area
# 0               False         False       False                  True
# 1               False         False        True                 False
# 2                True         False       False                 False
# 3               False         False       False                  True
# 4               False         False       False                  True
# ...               ...           ...         ...                   ...
# 13315            True         False       False                 False
# 13316           False         False       False                  True
# 13317            True         False       False                 False
# 13318           False         False       False                  True
# 13319           False         False       False                  True
#
# [13320 rows x 4 columns]

# %% [markdown]
# ### now we get encoding value for area , so we can do concat this df1 in our final data, so we can drop area_type

# %%
final_df = pd.concat([df,df1],axis=1).drop('area_type',axis=1)

# %%
final_df
# Out:
#         availability       size  society total_sqft  bath  balcony   price  \
# 0             19-Dec      2 BHK  Coomee        1056   2.0      1.0   39.07
# 1      Ready To Move  4 Bedroom  Theanmp       2600   5.0      3.0  120.00
# 2      Ready To Move      3 BHK      NaN       1440   2.0      3.0   62.00
# 3      Ready To Move      3 BHK  Soiewre       1521   3.0      1.0   95.00
# 4      Ready To Move      2 BHK      NaN       1200   2.0      1.0   51.00
# ...              ...        ...      ...        ...   ...      ...     ...
# 13315  Ready To Move  5 Bedroom  ArsiaEx       3453   4.0      0.0  231.00
# 13316  Ready To Move      4 BHK      NaN       3600   5.0      NaN  400.00
# 13317  Ready To Move      2 BHK  Mahla T       1141   2.0      1.0   60.00
# 13318         18-Jun      4 BHK  SollyCl       4689   4.0      1.0  488.00
# 13319  Ready To Move      1 BHK      NaN        550   1.0      1.0   17.00
#
# ...

# %% [markdown]
# ### now in size feature already encode 2bhk,3bhk etc. but we required only numrical value

# %%
final_df['size'] = final_df['size'].apply(lambda x:x.split(' ')[0])  ## here erroe occures because our size in dtype object
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Cell In[26], line 1
# ----> 1 final_df['size'] = final_df['size'].apply(lambda x:x.split(' ')[0])
#
# File C:\ProgramData\anaconda3\Lib\site-packages\pandas\core\series.py:4764, in Series.apply(self, func, convert_dtype, args, by_row, **kwargs)
#    4629 def apply(
#    4630     self,
#    4631     func: AggFuncType,
#    (...)
#    4636     **kwargs,
#    4637 ) -> DataFrame | Series:
#    4638     """
#    4639     Invoke function on values of Series.
#    4640
#    (...)
#    4755     dtype: float64
#    4756     """
#    4757     return SeriesApply(
#    4758         self,
#    4759         func,
#    4760         convert_dtype=convert_dtype,
#    4761         by_row=by_row,
#    4762         args=args,
#    4763         kwargs=kwargs,
# -> 4764     ).apply()
#
# ...

# %%
final_df['size'] = final_df['size'].apply(lambda x:str(x).split(' ')[0]) ### here only take this size in str

# %%
final_df
# Out:
#         availability size  society total_sqft  bath  balcony   price  \
# 0             19-Dec    2  Coomee        1056   2.0      1.0   39.07
# 1      Ready To Move    4  Theanmp       2600   5.0      3.0  120.00
# 2      Ready To Move    3      NaN       1440   2.0      3.0   62.00
# 3      Ready To Move    3  Soiewre       1521   3.0      1.0   95.00
# 4      Ready To Move    2      NaN       1200   2.0      1.0   51.00
# ...              ...  ...      ...        ...   ...      ...     ...
# 13315  Ready To Move    5  ArsiaEx       3453   4.0      0.0  231.00
# 13316  Ready To Move    4      NaN       3600   5.0      NaN  400.00
# 13317  Ready To Move    2  Mahla T       1141   2.0      1.0   60.00
# 13318         18-Jun    4  SollyCl       4689   4.0      1.0  488.00
# 13319  Ready To Move    1      NaN        550   1.0      1.0   17.00
#
#               site_location  Built-up  Area  Carpet  Area  Plot  Area  \
# ...

# %% [markdown]
# ## Now by using OneHotEncoding

# %%
from sklearn.preprocessing import OneHotEncoder

# %%
obj = OneHotEncoder

# %%
df2= OneHotEncoder(drop='first',sparse_output=False).fit_transform(df[['area_type']])

# %%
pd.concat([pd.DataFrame(df2,columns=['Carpet Area','Plot Area','Super built-up Area','Built-up Area']),df], axis=1)
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[39], line 1
# ----> 1 pd.concat([pd.DataFrame(df2,columns=['Carpet Area','Plot Area','Super built-up Area','Built-up Area']),df], axis=1)
#
# File C:\ProgramData\anaconda3\Lib\site-packages\pandas\core\frame.py:782, in DataFrame.__init__(self, data, index, columns, dtype, copy)
#     771         mgr = dict_to_mgr(
#     772             # error: Item "ndarray" of "Union[ndarray, Series, Index]" has no
#     773             # attribute "name"
#    (...)
#     779             copy=_copy,
#     780         )
#     781     else:
# --> 782         mgr = ndarray_to_mgr(
#     783             data,
#     784             index,
#     785             columns,
#     786             dtype=dtype,
#     787             copy=copy,
#     788             typ=manager,
#     789         )
# ...

# %% [markdown]
# ### Here first column drop  because of size of column matter in df having 3 and df2 having 4

# %%
pd.concat([pd.DataFrame(df2,columns=['Carpet Area','Plot Area','Super built-up Area']),df], axis=1)
# Out:
#        Carpet Area  Plot Area  Super built-up Area             area_type  \
# 0              0.0        0.0                  1.0  Super built-up  Area
# 1              0.0        1.0                  0.0            Plot  Area
# 2              0.0        0.0                  0.0        Built-up  Area
# 3              0.0        0.0                  1.0  Super built-up  Area
# 4              0.0        0.0                  1.0  Super built-up  Area
# ...            ...        ...                  ...                   ...
# 13315          0.0        0.0                  0.0        Built-up  Area
# 13316          0.0        0.0                  1.0  Super built-up  Area
# 13317          0.0        0.0                  0.0        Built-up  Area
# 13318          0.0        0.0                  1.0  Super built-up  Area
# 13319          0.0        0.0                  1.0  Super built-up  Area
#
#         availability       size  society total_sqft  bath  balcony   price  \
# ...

# %% [markdown]
# ## Ordinal encoding

# %%
from sklearn.preprocessing import OrdinalEncoder

# %%
obj = OrdinalEncoder()

# %%
final_df['society'].value_counts()
# Out:
# society
# GrrvaGr    80
# PrarePa    76
# Sryalan    59
# Prtates    59
# GMown E    56
#            ..
# Amionce     1
# JaghtDe     1
# Jauraht     1
# Brity U     1
# RSntsAp     1
# Name: count, Length: 2688, dtype: int64

# %%
final_df['society'] = final_df['society'].fillna(final_df['society'].mode()[0])

# %%
final_df
# Out:
#         availability size  society total_sqft  bath  balcony   price  \
# 0             19-Dec    2  Coomee        1056   2.0      1.0   39.07
# 1      Ready To Move    4  Theanmp       2600   5.0      3.0  120.00
# 2      Ready To Move    3  GrrvaGr       1440   2.0      3.0   62.00
# 3      Ready To Move    3  Soiewre       1521   3.0      1.0   95.00
# 4      Ready To Move    2  GrrvaGr       1200   2.0      1.0   51.00
# ...              ...  ...      ...        ...   ...      ...     ...
# 13315  Ready To Move    5  ArsiaEx       3453   4.0      0.0  231.00
# 13316  Ready To Move    4  GrrvaGr       3600   5.0      NaN  400.00
# 13317  Ready To Move    2  Mahla T       1141   2.0      1.0   60.00
# 13318         18-Jun    4  SollyCl       4689   4.0      1.0  488.00
# 13319  Ready To Move    1  GrrvaGr        550   1.0      1.0   17.00
#
#               site_location  Built-up  Area  Carpet  Area  Plot  Area  \
# ...

# %%
final_df.isnull().sum()
# Out:
# availability              0
# size                      0
# society                   0
# total_sqft                0
# bath                     73
# balcony                 609
# price                     0
# site_location             1
# Built-up  Area            0
# Carpet  Area              0
# Plot  Area                0
# Super built-up  Area      0
# dtype: int64

# %%
final_df['society'].value_counts()
# Out:
# society
# GrrvaGr    5582
# PrarePa      76
# Sryalan      59
# Prtates      59
# GMown E      56
#            ...
# Amionce       1
# JaghtDe       1
# Jauraht       1
# Brity U       1
# RSntsAp       1
# Name: count, Length: 2688, dtype: int64

# %%
final_df['ord_society'] = obj.fit_transform(final_df['society'].values.reshape(-1, 1))

# %%
final_df  #  here encoding done for society
# Out:
#         availability size  society total_sqft  bath  balcony   price  \
# 0             19-Dec    2  Coomee        1056   2.0      1.0   39.07
# 1      Ready To Move    4  Theanmp       2600   5.0      3.0  120.00
# 2      Ready To Move    3  GrrvaGr       1440   2.0      3.0   62.00
# 3      Ready To Move    3  Soiewre       1521   3.0      1.0   95.00
# 4      Ready To Move    2  GrrvaGr       1200   2.0      1.0   51.00
# ...              ...  ...      ...        ...   ...      ...     ...
# 13315  Ready To Move    5  ArsiaEx       3453   4.0      0.0  231.00
# 13316  Ready To Move    4  GrrvaGr       3600   5.0      NaN  400.00
# 13317  Ready To Move    2  Mahla T       1141   2.0      1.0   60.00
# 13318         18-Jun    4  SollyCl       4689   4.0      1.0  488.00
# 13319  Ready To Move    1  GrrvaGr        550   1.0      1.0   17.00
#
#               site_location  Built-up  Area  Carpet  Area  Plot  Area  \
# ...

# %%
d = {'name':['pravin','akash','jon','justin'],
     'grade':['D','A','D','o'],
     'color':['red','green','black','yellow'],
     'city':['pune','mumbai','chennai','delhi']
}

# %%
df = pd.DataFrame(d)

# %%
df
# Out:
#      name grade   color     city
# 0  pravin     D     red     pune
# 1   akash     A   green   mumbai
# 2     jon     D   black  chennai
# 3  justin     o  yellow    delhi

# %%
from sklearn.preprocessing import OneHotEncoder

# %%
df1 = pd.get_dummies(df['city'])

# %%
df2 = pd.concat([df1,df],axis=1)

# %%
df2
# Out:
#    chennai  delhi  mumbai   pune    name grade   color     city
# 0    False  False   False   True  pravin     D     red     pune
# 1    False  False    True  False   akash     A   green   mumbai
# 2     True  False   False  False     jon     D   black  chennai
# 3    False   True   False  False  justin     o  yellow    delhi

# %%
df2.drop('city',axis=1,inplace=True)

# %%
df2
# Out:
#    chennai  delhi  mumbai   pune    name grade   color
# 0    False  False   False   True  pravin     D     red
# 1    False  False    True  False   akash     A   green
# 2     True  False   False  False     jon     D   black
# 3    False   True   False  False  justin     o  yellow

# %%
df['color_encode'] = OrdinalEncoder().fit_transform(df['color'].values.reshape(-1,1))

# %%
df
# Out:
#      name grade   color     city  color_encode
# 0  pravin     D     red     pune           2.0
# 1   akash     A   green   mumbai           1.0
# 2     jon     D   black  chennai           0.0
# 3  justin     o  yellow    delhi           3.0

# %%
df['grade_encode'] = OrdinalEncoder().fit_transform(df['grade'].values.reshape(-1,1))

# %%
df
# Out:
#      name grade   color     city  color_encode  grade_encode
# 0  pravin     D     red     pune           2.0           1.0
# 1   akash     A   green   mumbai           1.0           0.0
# 2     jon     D   black  chennai           0.0           1.0
# 3  justin     o  yellow    delhi           3.0           2.0

# %%
df_final = pd.concat([df1,df],axis=1)

# %%
df_final
# Out:
#    chennai  delhi  mumbai   pune    name grade   color     city  color_encode  \
# 0    False  False   False   True  pravin     D     red     pune           2.0
# 1    False  False    True  False   akash     A   green   mumbai           1.0
# 2     True  False   False  False     jon     D   black  chennai           0.0
# 3    False   True   False  False  justin     o  yellow    delhi           3.0
#
#    grade_encode
# 0           1.0
# 1           0.0
# 2           1.0
# 3           2.0

# %%
df_final.drop(['city','grade','color'],axis=1,inplace=True)

# %%
df_final
# Out:
#    chennai  delhi  mumbai   pune    name  color_encode  grade_encode
# 0    False  False   False   True  pravin           2.0           1.0
# 1    False  False    True  False   akash           1.0           0.0
# 2     True  False   False  False     jon           0.0           1.0
# 3    False   True   False  False  justin           3.0           2.0
